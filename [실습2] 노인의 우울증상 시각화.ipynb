# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 2017년 가구 형태별 응답자 수 파이차트 시각화

# %%
# 예제

# %% [markdown]
# # 2017년 교육 형태별 정상/우울증 비교 막대그래프

# %%
# 예제
